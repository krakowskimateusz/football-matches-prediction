# %%
import numpy as np
import pandas as pd
import warnings

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('soccerData.csv')
df['date']= pd.to_datetime(df['date'])

# %%
df
# Out:
#            date  match_id home_team_name away_team_name  home_team_goal_count  \
# 0    2000-08-19    213456       Charlton       Man City                     4
# 1    2000-08-19    213457        Chelsea       West Ham                     4
# 2    2000-08-19    213458       Coventry  Middlesbrough                     1
# 3    2000-08-19    213459          Derby    Southampton                     2
# 4    2000-08-19    213460          Leeds        Everton                     2
# ...         ...       ...            ...            ...                   ...
# 8845 2023-11-04    222301      Sheff Utd         Wolves                     2
# 8846 2023-11-04    222302      Newcastle        Arsenal                     1
# 8847 2023-11-05    222303   Nottm Forest    Aston Villa                     2
# 8848 2023-11-05    222304          Luton      Liverpool                     1
# 8849 2023-11-06    222305      Tottenham        Chelsea                     1
#
#       away_team_goal_count  home_team_half_time_goal_count  \
# 0                        0                               2
# 1                        2                               1
# 2                        3                               1
# 3                        2                               1
# 4                        0                               2
# ...                    ...                             ...
# 8845                     1                               0
# 8846                     0                               0
# 8847                     0                               1
# 8848                     1                               0
# 8849                     4                               1
#
#       away_team_half_time_goal_count  home_team_shots  away_team_shots  \
# 0                                  0               17                8
# 1                                  0               17               12
# 2                                  1                6               16
# 3                                  2                6               13
# 4                                  0               17               12
# ...                              ...              ...              ...
# 8845                               0               11               10
# 8846                               0                9               14
# 8847                               0                5               13
# 8848                               0                8               24
# 8849                               1                8               17
#
#       home_team_shots_on_target  away_team_shots_on_target  home_team_fouls  \
# 0                            14                          4               13
# 1                            10                          5               19
# 2                             3                          9               15
# 3                             4                          6               11
# 4                             8                          6               21
# ...                         ...                        ...              ...
# 8845                          2                          3               13
# 8846                          2                          1               14
# 8847                          3                          3                6
# 8848                          5                          6                7
# 8849                          5                          8               12
#
#       away_team_fouls  home_team_corner_count  away_team_corner_count  \
# 0                  12                       6                       6
# 1                  14                       7                       7
# 2                  21                       8                       4
# 3                  13                       5                       8
# 4                  20                       6                       4
# ...               ...                     ...                     ...
# 8845               10                       4                       4
# 8846                9                       0                      11
# 8847                9                       0                      10
# 8848               13                       4                       7
# 8849               21                       1                       6
#
#       home_team_yellow  away_team_yellow  home_team_red  away_team_red
# 0                    1                 2              0              0
# 1                    1                 2              0              0
# 2                    5                 3              1              0
# 3                    1                 1              0              0
# 4                    1                 3              0              0
# ...                ...               ...            ...            ...
# 8845                 2                 3              0              0
# 8846                 5                 1              0              0
# 8847                 1                 1              0              0
# 8848                 1                 1              0              0
# 8849                 1                 5              2              0
#
# [8850 rows x 20 columns]

# %%
raw_match_stats = df[[
                'date',
                'match_id',
                'home_team_name',
                'away_team_name',
                'home_team_goal_count', 
                'away_team_goal_count',
                'home_team_half_time_goal_count',
                'away_team_half_time_goal_count',
                'home_team_shots',
                'away_team_shots',
                'home_team_shots_on_target',
                'away_team_shots_on_target',
                'home_team_fouls',
                'away_team_fouls',
                'home_team_corner_count',
                'away_team_corner_count',
                'home_team_yellow',
                'away_team_yellow',
                'home_team_red',
                'away_team_red'
                ]]


raw_match_stats.sort_values(by=['date'], ascending=False, inplace=True)
raw_match_stats.dropna(inplace=True)

raw_match_stats.loc[raw_match_stats['home_team_goal_count'] == raw_match_stats['away_team_goal_count'], 'home_team_result'] = 1
raw_match_stats.loc[raw_match_stats['home_team_goal_count'] > raw_match_stats['away_team_goal_count'], 'home_team_result'] = 3
raw_match_stats.loc[raw_match_stats['home_team_goal_count'] < raw_match_stats['away_team_goal_count'], 'home_team_result'] = 0

raw_match_stats.loc[raw_match_stats['home_team_goal_count'] == raw_match_stats['away_team_goal_count'], 'away_team_result'] = 1
raw_match_stats.loc[raw_match_stats['home_team_goal_count'] > raw_match_stats['away_team_goal_count'], 'away_team_result'] = 0
raw_match_stats.loc[raw_match_stats['home_team_goal_count'] < raw_match_stats['away_team_goal_count'], 'away_team_result'] = 3

# %%
home_team_stats = raw_match_stats[[
 'date',
 'match_id',
 'home_team_name',
 'home_team_goal_count',
 'home_team_half_time_goal_count',
 'home_team_corner_count',
 'home_team_shots',
 'home_team_shots_on_target',
 'home_team_fouls',
 'home_team_yellow',
 'home_team_red',
 'home_team_result',
 'away_team_goal_count',
 'away_team_half_time_goal_count',
 'away_team_corner_count',
 'away_team_shots',
 'away_team_shots_on_target',
 'away_team_fouls',
 'away_team_yellow',
 'away_team_red']]

home_team_stats = home_team_stats.rename(columns={'home_team_name':'name',
                                                'home_team_goal_count':'goalsScored',
                                                'home_team_half_time_goal_count':'halfTimeGoalsScored',
                                                'home_team_corner_count':'cornerCount',
                                                'home_team_shots':'shots',
                                                'home_team_shots_on_target':'shotsOnTarget',
                                                'home_team_fouls':'foulsConceded',
                                                'home_team_yellow':'yellowConceded',
                                                'home_team_red':'redConceded',
                                                'home_team_result':'result',
                                                'away_team_goal_count':'goalsConceded',
                                                'away_team_half_time_goal_count':'halfTimeGoalsConceded',
                                                'away_team_corner_count':'cornersConceded',
                                                'away_team_shots':'shotsConceded',
                                                'away_team_shots_on_target':'shotsOnTargetConceded',
                                                'away_team_fouls':'foulsReceived',
                                                'away_team_yellow':'yellowOpponent',
                                                'away_team_red':'redOpponent'})

# %%
away_team_stats = raw_match_stats[[
 'date',
 'match_id',
 'away_team_name',
 'away_team_goal_count',
 'away_team_half_time_goal_count',
 'away_team_corner_count',
 'away_team_shots',
 'away_team_shots_on_target',
 'away_team_fouls',
 'away_team_yellow',
 'away_team_red',
 'away_team_result',
 'home_team_goal_count',
 'home_team_half_time_goal_count',
 'home_team_corner_count',
 'home_team_shots',
 'home_team_shots_on_target',
 'home_team_fouls',
 'home_team_yellow',
 'home_team_red',]]

away_team_stats = away_team_stats.rename(columns={'away_team_name':'name',
                                                'away_team_goal_count':'goalsScored',
                                                'away_team_half_time_goal_count':'halfTimeGoalsScored',
                                                'away_team_corner_count':'cornerCount',
                                                'away_team_shots':'shots',
                                                'away_team_shots_on_target':'shotsOnTarget',
                                                'away_team_fouls':'foulsConceded',
                                                'away_team_yellow':'yellowConceded',
                                                'away_team_red':'redConceded',
                                                'away_team_result':'result',
                                                'home_team_goal_count':'goalsConceded',
                                                'home_team_half_time_goal_count':'halfTimeGoalsConceded',
                                                'home_team_corner_count':'cornersConceded',
                                                'home_team_shots':'shotsConceded',
                                                'home_team_shots_on_target':'shotsOnTargetConceded',
                                                'home_team_fouls':'foulsReceived',
                                                'home_team_yellow':'yellowOpponent',
                                                'home_team_red':'redOpponent'})

# %%
home_team_stats['home_or_away']='Home'
away_team_stats['home_or_away']='Away'

# %%
team_stats_per_match = pd.concat([home_team_stats,away_team_stats])

# %%
team_stats_per_match
# Out:
#            date  match_id          name  goalsScored  halfTimeGoalsScored  \
# 8849 2023-11-06    222305     Tottenham            1                    1
# 8848 2023-11-05    222304         Luton            1                    0
# 8847 2023-11-05    222303  Nottm Forest            2                    1
# 8843 2023-11-04    222299       Everton            1                    1
# 8840 2023-11-04    222296        Fulham            0                    0
# ...         ...       ...           ...          ...                  ...
# 1    2000-08-19    213457      West Ham            2                    0
# 6    2000-08-19    213462      Bradford            0                    0
# 7    2000-08-19    213463       Arsenal            0                    0
# 8    2000-08-19    213464       Ipswich            1                    1
# 0    2000-08-19    213456      Man City            0                    0
#
#       cornerCount  shots  shotsOnTarget  foulsConceded  yellowConceded  ...  \
# 8849            1      8              5             12               1  ...
# 8848            4      8              5              7               1  ...
# 8847            0      5              3              6               1  ...
# 8843            3     10              4             15               4  ...
# 8840            9     18              3              9               5  ...
# ...           ...    ...            ...            ...             ...  ...
# 1               7     12              5             14               2  ...
# 6               1      3              2              8               1  ...
# 7               9     14              7             21               1  ...
# 8               4     15              5             13               0  ...
# 0               6      8              4             12               2  ...
#
#       result  goalsConceded  halfTimeGoalsConceded  cornersConceded  \
# 8849     0.0              4                      1                6
# 8848     1.0              1                      0                7
# 8847     3.0              0                      0               10
# 8843     1.0              1                      0                3
# 8840     0.0              1                      0                4
# ...      ...            ...                    ...              ...
# 1        0.0              4                      1                7
# 6        0.0              1                      0                6
# 7        0.0              1                      0                2
# 8        0.0              3                      2                3
# 0        0.0              4                      2                6
#
#       shotsConceded  shotsOnTargetConceded  foulsReceived  yellowOpponent  \
# 8849             17                      8             21               5
# 8848             24                      6             13               1
# 8847             13                      3              9               1
# 8843              7                      2              5               2
# 8840             12                      5             15               2
# ...             ...                    ...            ...             ...
# 1                17                     10             19               1
# 6                16                     10              8               1
# 7                 8                      2             10               3
# 8                20                      6             14               0
# 0                17                     14             13               1
#
#       redOpponent  home_or_away
# 8849            0          Home
# 8848            0          Home
# 8847            0          Home
# 8843            0          Home
# 8840            0          Home
# ...           ...           ...
# 1               0          Away
# 6               0          Away
# 7               0          Away
# 8               0          Away
# 0               0          Away
#
# [17700 rows x 21 columns]

# %%
avg_lastFive_stat_columns = [
                    'average_goalsScored_last_five',
                    'average_halfTimeGoalsScored_last_five',
                    'average_cornerCount_last_five',
                    'average_shots_last_five',
                    'average_shotsOnTarget_last_five',
                    'average_foulsConceded_last_five',
                    'average_yellowConceded_last_five',
                    'average_redConceded_last_five',
                    'average_result_last_five',
                    'average_goalsConceded_last_five',
                    'average_halfTimeGoalsConceded_last_five',
                    'average_cornersConceded_last_five',
                    'average_shotsConceded_last_five',
                    'average_shotsOnTargetConceded_last_five',
                    'average_foulsReceived_last_five',
                    'average_yellowOpponent_last_five',
                    'average_redOpponent_last_five'
                    ]

lastFive_stats_list = []
for index, row in team_stats_per_match.iterrows():
    team_stats_last_five_matches = team_stats_per_match.loc[
        (team_stats_per_match['name'] == row['name']) & 
        (team_stats_per_match['date'] < row['date'])
    ].sort_values(by=['date'], ascending=False)
    
    lastFive_stats_list.append(
        team_stats_last_five_matches.iloc[0:5, 3:-1].mean(axis=0).values[0:18]
    )

avg_lastFive_stats_per_team = pd.DataFrame(
    lastFive_stats_list, 
    columns=avg_lastFive_stat_columns
)

avg_lastFive_stats_per_team.index = team_stats_per_match.index

team_stats_with_averages = pd.concat(
    [team_stats_per_match, avg_lastFive_stats_per_team], 
    axis=1
)

# %%
team_stats_with_averages
# Out:
#            date  match_id          name  goalsScored  halfTimeGoalsScored  \
# 8849 2023-11-06    222305     Tottenham            1                    1
# 8848 2023-11-05    222304         Luton            1                    0
# 8847 2023-11-05    222303  Nottm Forest            2                    1
# 8843 2023-11-04    222299       Everton            1                    1
# 8840 2023-11-04    222296        Fulham            0                    0
# ...         ...       ...           ...          ...                  ...
# 1    2000-08-19    213457      West Ham            2                    0
# 6    2000-08-19    213462      Bradford            0                    0
# 7    2000-08-19    213463       Arsenal            0                    0
# 8    2000-08-19    213464       Ipswich            1                    1
# 0    2000-08-19    213456      Man City            0                    0
#
#       cornerCount  shots  shotsOnTarget  foulsConceded  yellowConceded  ...  \
# 8849            1      8              5             12               1  ...
# 8848            4      8              5              7               1  ...
# 8847            0      5              3              6               1  ...
# 8843            3     10              4             15               4  ...
# 8840            9     18              3              9               5  ...
# ...           ...    ...            ...            ...             ...  ...
# 1               7     12              5             14               2  ...
# 6               1      3              2              8               1  ...
# 7               9     14              7             21               1  ...
# 8               4     15              5             13               0  ...
# 0               6      8              4             12               2  ...
#
#       average_redConceded_last_five  average_result_last_five  \
# 8849                            0.2                       2.6
# 8848                            0.0                       0.8
# 8847                            0.2                       0.6
# 8843                            0.2                       1.8
# 8840                            0.0                       1.0
# ...                             ...                       ...
# 1                               NaN                       NaN
# 6                               NaN                       NaN
# 7                               NaN                       NaN
# 8                               NaN                       NaN
# 0                               NaN                       NaN
#
#       average_goalsConceded_last_five  \
# 8849                              0.8
# 8848                              1.8
# 8847                              1.6
# 8843                              1.0
# 8840                              1.2
# ...                               ...
# 1                                 NaN
# 6                                 NaN
# 7                                 NaN
# 8                                 NaN
# 0                                 NaN
#
#       average_halfTimeGoalsConceded_last_five  \
# 8849                                      0.4
# 8848                                      0.6
# 8847                                      0.8
# 8843                                      0.6
# 8840                                      0.8
# ...                                       ...
# 1                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 0                                         NaN
#
#       average_cornersConceded_last_five  average_shotsConceded_last_five  \
# 8849                                7.4                             12.0
# 8848                                5.0                             17.6
# 8847                                6.0                             13.4
# 8843                                6.0                             14.0
# 8840                                3.6                             11.2
# ...                                 ...                              ...
# 1                                   NaN                              NaN
# 6                                   NaN                              NaN
# 7                                   NaN                              NaN
# 8                                   NaN                              NaN
# 0                                   NaN                              NaN
#
#       average_shotsOnTargetConceded_last_five  \
# 8849                                      3.6
# 8848                                      5.4
# 8847                                      4.6
# 8843                                      3.2
# 8840                                      4.2
# ...                                       ...
# 1                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 0                                         NaN
#
#       average_foulsReceived_last_five  average_yellowOpponent_last_five  \
# 8849                             15.6                               2.2
# 8848                              8.8                               1.8
# 8847                              8.4                               1.4
# 8843                             10.0                               2.0
# 8840                             10.8                               2.2
# ...                               ...                               ...
# 1                                 NaN                               NaN
# 6                                 NaN                               NaN
# 7                                 NaN                               NaN
# 8                                 NaN                               NaN
# 0                                 NaN                               NaN
#
#       average_redOpponent_last_five
# 8849                            0.4
# 8848                            0.2
# 8847                            0.2
# 8843                            0.0
# 8840                            0.0
# ...                             ...
# 1                               NaN
# 6                               NaN
# 7                               NaN
# 8                               NaN
# 0                               NaN
#
# [17700 rows x 38 columns]

# %%
team_stats_with_averages['season_start_year'] = team_stats_with_averages['date'].apply(lambda d: d.year if d.month >= 8 else d.year - 1)
team_stats_with_averages['season'] = team_stats_with_averages['season_start_year'].astype(str) + '/' + (team_stats_with_averages['season_start_year'] + 1).astype(str)
team_stats_with_averages.drop(columns=['season_start_year'], inplace=True)

# %%
team_stats_with_averages
# Out:
#            date  match_id          name  goalsScored  halfTimeGoalsScored  \
# 8849 2023-11-06    222305     Tottenham            1                    1
# 8848 2023-11-05    222304         Luton            1                    0
# 8847 2023-11-05    222303  Nottm Forest            2                    1
# 8843 2023-11-04    222299       Everton            1                    1
# 8840 2023-11-04    222296        Fulham            0                    0
# ...         ...       ...           ...          ...                  ...
# 1    2000-08-19    213457      West Ham            2                    0
# 6    2000-08-19    213462      Bradford            0                    0
# 7    2000-08-19    213463       Arsenal            0                    0
# 8    2000-08-19    213464       Ipswich            1                    1
# 0    2000-08-19    213456      Man City            0                    0
#
#       cornerCount  shots  shotsOnTarget  foulsConceded  yellowConceded  ...  \
# 8849            1      8              5             12               1  ...
# 8848            4      8              5              7               1  ...
# 8847            0      5              3              6               1  ...
# 8843            3     10              4             15               4  ...
# 8840            9     18              3              9               5  ...
# ...           ...    ...            ...            ...             ...  ...
# 1               7     12              5             14               2  ...
# 6               1      3              2              8               1  ...
# 7               9     14              7             21               1  ...
# 8               4     15              5             13               0  ...
# 0               6      8              4             12               2  ...
#
#       average_result_last_five  average_goalsConceded_last_five  \
# 8849                       2.6                              0.8
# 8848                       0.8                              1.8
# 8847                       0.6                              1.6
# 8843                       1.8                              1.0
# 8840                       1.0                              1.2
# ...                        ...                              ...
# 1                          NaN                              NaN
# 6                          NaN                              NaN
# 7                          NaN                              NaN
# 8                          NaN                              NaN
# 0                          NaN                              NaN
#
#       average_halfTimeGoalsConceded_last_five  \
# 8849                                      0.4
# 8848                                      0.6
# 8847                                      0.8
# 8843                                      0.6
# 8840                                      0.8
# ...                                       ...
# 1                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 0                                         NaN
#
#       average_cornersConceded_last_five  average_shotsConceded_last_five  \
# 8849                                7.4                             12.0
# 8848                                5.0                             17.6
# 8847                                6.0                             13.4
# 8843                                6.0                             14.0
# 8840                                3.6                             11.2
# ...                                 ...                              ...
# 1                                   NaN                              NaN
# 6                                   NaN                              NaN
# 7                                   NaN                              NaN
# 8                                   NaN                              NaN
# 0                                   NaN                              NaN
#
#       average_shotsOnTargetConceded_last_five  \
# 8849                                      3.6
# 8848                                      5.4
# 8847                                      4.6
# 8843                                      3.2
# 8840                                      4.2
# ...                                       ...
# 1                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 0                                         NaN
#
#       average_foulsReceived_last_five  average_yellowOpponent_last_five  \
# 8849                             15.6                               2.2
# 8848                              8.8                               1.8
# 8847                              8.4                               1.4
# 8843                             10.0                               2.0
# 8840                             10.8                               2.2
# ...                               ...                               ...
# 1                                 NaN                               NaN
# 6                                 NaN                               NaN
# 7                                 NaN                               NaN
# 8                                 NaN                               NaN
# 0                                 NaN                               NaN
#
#       average_redOpponent_last_five     season
# 8849                            0.4  2023/2024
# 8848                            0.2  2023/2024
# 8847                            0.2  2023/2024
# 8843                            0.0  2023/2024
# 8840                            0.0  2023/2024
# ...                             ...        ...
# 1                               NaN  2000/2001
# 6                               NaN  2000/2001
# 7                               NaN  2000/2001
# 8                               NaN  2000/2001
# 0                               NaN  2000/2001
#
# [17700 rows x 39 columns]

# %% [markdown]
# Tworzenie kolumny z informacją czy to benjaminek

# %%
seasons = sorted(team_stats_with_averages['season'].unique())
teams_by_season = (
    team_stats_with_averages.groupby('season')['name']
    .unique()
    .apply(set)
    .to_dict()
)

promoted_dict = {}

promoted_dict['1999/2000'] = set(['Sunderland', 'Bradford City', 'Watford'])


for i in range(1, len(seasons)):
    current_season = seasons[i]
    prev_season = seasons[i - 1]
    current_teams = teams_by_season.get(current_season, set())
    prev_teams = teams_by_season.get(prev_season, set())
    promoted_teams = list(current_teams - prev_teams)
    promoted_dict[current_season] = set(promoted_teams)

team_stats_with_averages['promoted'] = team_stats_with_averages.apply(
    lambda row: int(row['name'] in promoted_dict.get(row['season'], set())),
    axis=1
)

# %%
team_stats_with_averages
# Out:
#            date  match_id          name  goalsScored  halfTimeGoalsScored  \
# 8849 2023-11-06    222305     Tottenham            1                    1
# 8848 2023-11-05    222304         Luton            1                    0
# 8847 2023-11-05    222303  Nottm Forest            2                    1
# 8843 2023-11-04    222299       Everton            1                    1
# 8840 2023-11-04    222296        Fulham            0                    0
# ...         ...       ...           ...          ...                  ...
# 1    2000-08-19    213457      West Ham            2                    0
# 6    2000-08-19    213462      Bradford            0                    0
# 7    2000-08-19    213463       Arsenal            0                    0
# 8    2000-08-19    213464       Ipswich            1                    1
# 0    2000-08-19    213456      Man City            0                    0
#
#       cornerCount  shots  shotsOnTarget  foulsConceded  yellowConceded  ...  \
# 8849            1      8              5             12               1  ...
# 8848            4      8              5              7               1  ...
# 8847            0      5              3              6               1  ...
# 8843            3     10              4             15               4  ...
# 8840            9     18              3              9               5  ...
# ...           ...    ...            ...            ...             ...  ...
# 1               7     12              5             14               2  ...
# 6               1      3              2              8               1  ...
# 7               9     14              7             21               1  ...
# 8               4     15              5             13               0  ...
# 0               6      8              4             12               2  ...
#
#       average_goalsConceded_last_five  \
# 8849                              0.8
# 8848                              1.8
# 8847                              1.6
# 8843                              1.0
# 8840                              1.2
# ...                               ...
# 1                                 NaN
# 6                                 NaN
# 7                                 NaN
# 8                                 NaN
# 0                                 NaN
#
#       average_halfTimeGoalsConceded_last_five  \
# 8849                                      0.4
# 8848                                      0.6
# 8847                                      0.8
# 8843                                      0.6
# 8840                                      0.8
# ...                                       ...
# 1                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 0                                         NaN
#
#       average_cornersConceded_last_five  average_shotsConceded_last_five  \
# 8849                                7.4                             12.0
# 8848                                5.0                             17.6
# 8847                                6.0                             13.4
# 8843                                6.0                             14.0
# 8840                                3.6                             11.2
# ...                                 ...                              ...
# 1                                   NaN                              NaN
# 6                                   NaN                              NaN
# 7                                   NaN                              NaN
# 8                                   NaN                              NaN
# 0                                   NaN                              NaN
#
#       average_shotsOnTargetConceded_last_five  \
# 8849                                      3.6
# 8848                                      5.4
# 8847                                      4.6
# 8843                                      3.2
# 8840                                      4.2
# ...                                       ...
# 1                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 0                                         NaN
#
#       average_foulsReceived_last_five  average_yellowOpponent_last_five  \
# 8849                             15.6                               2.2
# 8848                              8.8                               1.8
# 8847                              8.4                               1.4
# 8843                             10.0                               2.0
# 8840                             10.8                               2.2
# ...                               ...                               ...
# 1                                 NaN                               NaN
# 6                                 NaN                               NaN
# 7                                 NaN                               NaN
# 8                                 NaN                               NaN
# 0                                 NaN                               NaN
#
#       average_redOpponent_last_five     season  promoted
# 8849                            0.4  2023/2024         0
# 8848                            0.2  2023/2024         1
# 8847                            0.2  2023/2024         0
# 8843                            0.0  2023/2024         0
# 8840                            0.0  2023/2024         0
# ...                             ...        ...       ...
# 1                               NaN  2000/2001         0
# 6                               NaN  2000/2001         0
# 7                               NaN  2000/2001         0
# 8                               NaN  2000/2001         0
# 0                               NaN  2000/2001         0
#
# [17700 rows x 40 columns]

# %% [markdown]
# Mam już:
#
# - średnie statystki z 5 ostatnich meczy drużyny gospodarzy i gości
# - informacje o tym czy dana drużyna w sezonie jest benjaminkiem

# %% [markdown]
# Dodanie:
# - seri meczów bez przegranej
# - seri meczów wygranych z rzędu

# %%
def calc_streaks(team_df):
    team_df = team_df.sort_values('date')
    
    win_streak = 0
    unbeaten_streak = 0
    
    win_streaks = []
    unbeaten_streaks = []
    
    for res in team_df['result']:
        win_streaks.append(win_streak)
        unbeaten_streaks.append(unbeaten_streak)
        
        if res == 3:
            win_streak += 1
            unbeaten_streak += 1
        elif res == 1:
            win_streak = 0
            unbeaten_streak += 1
        else:
            win_streak = 0
            unbeaten_streak = 0
    
    team_df['win_streak_before_match'] = win_streaks
    team_df['unbeaten_streak_before_match'] = unbeaten_streaks
    
    return team_df

team_stats_with_averages = team_stats_with_averages.groupby('name', group_keys=False).apply(calc_streaks)

# %%
team_stats_with_averages
# Out:
#            date  match_id     name  goalsScored  halfTimeGoalsScored  \
# 7    2000-08-19    213463  Arsenal            0                    0
# 10   2000-08-21    213466  Arsenal            2                    1
# 19   2000-08-26    213475  Arsenal            5                    1
# 34   2000-09-06    213490  Arsenal            2                    0
# 39   2000-09-09    213495  Arsenal            1                    0
# ...         ...       ...      ...          ...                  ...
# 8805 2023-09-30    222261   Wolves            2                    1
# 8818 2023-10-08    222274   Wolves            1                    0
# 8821 2023-10-21    222277   Wolves            2                    0
# 8834 2023-10-28    222290   Wolves            2                    1
# 8845 2023-11-04    222301   Wolves            1                    0
#
#       cornerCount  shots  shotsOnTarget  foulsConceded  yellowConceded  ...  \
# 7               9     14              7             21               1  ...
# 10             10     17             12             25               2  ...
# 19              8     18              9             12               0  ...
# 34              6     13              5             22               1  ...
# 39             10     18             11             13               2  ...
# ...           ...    ...            ...            ...             ...  ...
# 8805            0      3              1             18               5  ...
# 8818            2      8              3             19               2  ...
# 8821           12     20              7             10               6  ...
# 8834            8     11              6             13               1  ...
# 8845            4     10              3             10               3  ...
#
#       average_cornersConceded_last_five  average_shotsConceded_last_five  \
# 7                                   NaN                              NaN
# 10                             2.000000                         8.000000
# 19                             6.500000                         7.500000
# 34                             5.333333                         7.333333
# 39                             5.750000                         8.500000
# ...                                 ...                              ...
# 8805                           5.600000                        16.600000
# 8818                           6.200000                        18.000000
# 8821                           6.800000                        18.600000
# 8834                           6.600000                        16.800000
# 8845                           7.200000                        16.200000
#
#       average_shotsOnTargetConceded_last_five  \
# 7                                         NaN
# 10                                   2.000000
# 19                                   3.000000
# 34                                   3.333333
# 39                                   3.750000
# ...                                       ...
# 8805                                 7.200000
# 8818                                 7.200000
# 8821                                 6.600000
# 8834                                 5.200000
# 8845                                 5.000000
#
#       average_foulsReceived_last_five  average_yellowOpponent_last_five  \
# 7                                 NaN                               NaN
# 10                              10.00                          3.000000
# 19                              15.00                          3.500000
# 34                              15.00                          2.666667
# 39                              15.25                          2.750000
# ...                               ...                               ...
# 8805                             9.80                          2.600000
# 8818                            10.00                          2.200000
# 8821                             9.80                          2.000000
# 8834                            10.40                          2.200000
# 8845                            12.60                          2.400000
#
#       average_redOpponent_last_five     season  promoted  \
# 7                               NaN  2000/2001         0
# 10                         0.000000  2000/2001         0
# 19                         1.000000  2000/2001         0
# 34                         0.666667  2000/2001         0
# 39                         0.500000  2000/2001         0
# ...                             ...        ...       ...
# 8805                       0.000000  2023/2024         0
# 8818                       0.000000  2023/2024         0
# 8821                       0.000000  2023/2024         0
# 8834                       0.200000  2023/2024         0
# 8845                       0.200000  2023/2024         0
#
#       win_streak_before_match  unbeaten_streak_before_match
# 7                           0                             0
# 10                          0                             0
# 19                          1                             1
# 34                          2                             2
# 39                          0                             3
# ...                       ...                           ...
# 8805                        0                             1
# 8818                        1                             2
# 8821                        0                             3
# 8834                        1                             4
# 8845                        0                             5
#
# [17700 rows x 42 columns]

# %%
home_team_stats = team_stats_with_averages[team_stats_with_averages['home_or_away'] == 'Home'].copy()
away_team_stats = team_stats_with_averages[team_stats_with_averages['home_or_away'] == 'Away'].copy()

home_cols = ['date', 'match_id'] + ['team_1_' + col for col in home_team_stats.columns if col not in ['date', 'match_id']]
away_cols = ['date', 'match_id'] + ['team_2_' + col for col in away_team_stats.columns if col not in ['date', 'match_id']]

home_team_stats.columns = home_cols
away_team_stats.columns = away_cols

match_stats = pd.merge(
    home_team_stats,
    away_team_stats,
    left_on=['match_id', 'date'],
    right_on=['match_id', 'date'],
    how='inner'
)

if 'team_1_season' in match_stats.columns and 'team_2_season' in match_stats.columns:
    match_stats = match_stats.drop(columns=['team_1_season', 'team_2_season'])

match_stats = match_stats.dropna().reset_index(drop=True)

# %%
match_stats
# Out:
#            date  match_id team_1_name  team_1_goalsScored  \
# 0    2000-08-21    213466     Arsenal                   2
# 1    2000-08-26    213475     Arsenal                   5
# 2    2000-09-16    213505     Arsenal                   2
# 3    2000-10-01    213532     Arsenal                   1
# 4    2000-10-14    213535     Arsenal                   1
# ...         ...       ...         ...                 ...
# 8810 2023-08-19    222209      Wolves                   1
# 8811 2023-09-16    222235      Wolves                   1
# 8812 2023-09-30    222261      Wolves                   2
# 8813 2023-10-08    222274      Wolves                   1
# 8814 2023-10-28    222290      Wolves                   2
#
#       team_1_halfTimeGoalsScored  team_1_cornerCount  team_1_shots  \
# 0                              1                  10            17
# 1                              1                   8            18
# 2                              1                   8            18
# 3                              1                   3             7
# 4                              0                   7            16
# ...                          ...                 ...           ...
# 8810                           0                   5            16
# 8811                           1                   4            11
# 8812                           1                   0             3
# 8813                           0                   2             8
# 8814                           1                   8            11
#
#       team_1_shotsOnTarget  team_1_foulsConceded  team_1_yellowConceded  ...  \
# 0                       12                    25                      2  ...
# 1                        9                    12                      0  ...
# 2                       13                     5                      1  ...
# 3                        5                    18                      2  ...
# 4                       10                    12                      1  ...
# ...                    ...                   ...                    ...  ...
# 8810                     5                    14                      3  ...
# 8811                     2                    10                      1  ...
# 8812                     1                    18                      5  ...
# 8813                     3                    19                      2  ...
# 8814                     6                    13                      1  ...
#
#       team_2_average_halfTimeGoalsConceded_last_five  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.4
# 3                                                0.4
# 4                                                0.6
# ...                                              ...
# 8810                                             1.0
# 8811                                             1.0
# 8812                                             0.4
# 8813                                             0.4
# 8814                                             0.2
#
#       team_2_average_cornersConceded_last_five  \
# 0                                          1.0
# 1                                          4.5
# 2                                          5.8
# 3                                          4.4
# 4                                          6.0
# ...                                        ...
# 8810                                       4.2
# 8811                                       3.2
# 8812                                       3.2
# 8813                                       4.2
# 8814                                       4.0
#
#       team_2_average_shotsConceded_last_five  \
# 0                                        3.0
# 1                                       10.5
# 2                                       13.2
# 3                                        9.4
# 4                                       11.4
# ...                                      ...
# 8810                                    12.2
# 8811                                    14.0
# 8812                                     7.0
# 8813                                    10.6
# 8814                                    10.0
#
#       team_2_average_shotsOnTargetConceded_last_five  \
# 0                                                2.0
# 1                                                6.0
# 2                                                5.8
# 3                                                4.4
# 4                                                5.4
# ...                                              ...
# 8810                                             4.4
# 8811                                             6.0
# 8812                                             2.6
# 8813                                             3.2
# 8814                                             2.2
#
#       team_2_average_foulsReceived_last_five  \
# 0                                        8.0
# 1                                       14.5
# 2                                       15.6
# 3                                       13.0
# 4                                        8.4
# ...                                      ...
# 8810                                    12.8
# 8811                                     9.0
# 8812                                    11.6
# 8813                                    12.6
# 8814                                    12.4
#
#       team_2_average_yellowOpponent_last_five  \
# 0                                         1.0
# 1                                         2.0
# 2                                         2.6
# 3                                         2.2
# 4                                         1.4
# ...                                       ...
# 8810                                      2.8
# 8811                                      1.6
# 8812                                      4.4
# 8813                                      2.2
# 8814                                      3.4
#
#       team_2_average_redOpponent_last_five  team_2_promoted  \
# 0                                      0.0                0
# 1                                      0.0                0
# 2                                      0.0                0
# 3                                      0.0                0
# 4                                      0.0                0
# ...                                    ...              ...
# 8810                                   0.0                0
# 8811                                   0.0                0
# 8812                                   0.0                0
# 8813                                   0.0                0
# 8814                                   0.0                0
#
#       team_2_win_streak_before_match  team_2_unbeaten_streak_before_match
# 0                                  1                                    1
# 1                                  0                                    0
# 2                                  0                                    1
# 3                                  0                                    7
# 4                                  1                                    4
# ...                              ...                                  ...
# 8810                               1                                    1
# 8811                               3                                   15
# 8812                               6                                    6
# 8813                               3                                    3
# 8814                               1                                    5
#
# [8815 rows x 80 columns]

# %%
match_stats.to_csv('match_stats_final.csv', index=False)

# %%
selected_columns = [
    'date',
    'match_id',
    'team_1_name',
    'team_1_goalsScored',
    'team_1_halfTimeGoalsScored',
    'team_1_cornerCount',
    'team_1_shots',
    'team_1_shotsOnTarget',
    'team_1_foulsConceded',
    'team_1_yellowConceded',
    'team_1_redConceded',
    'team_1_result',
    'team_1_goalsConceded',
    'team_1_halfTimeGoalsConceded',
    'team_1_cornersConceded',
    'team_1_shotsConceded',
    'team_1_shotsOnTargetConceded',
    'team_1_foulsReceived',
    'team_1_yellowOpponent',
    'team_1_redOpponent',
    'team_1_home_or_away',
    'team_2_name',
    'team_2_goalsScored',
    'team_2_halfTimeGoalsScored',
    'team_2_cornerCount',
    'team_2_shots',
    'team_2_shotsOnTarget',
    'team_2_foulsConceded',
    'team_2_yellowConceded',
    'team_2_redConceded',
    'team_2_result',
    'team_2_goalsConceded',
    'team_2_halfTimeGoalsConceded',
    'team_2_cornersConceded',
    'team_2_shotsConceded',
    'team_2_shotsOnTargetConceded',
    'team_2_foulsReceived',
    'team_2_yellowOpponent',
    'team_2_redOpponent',
    'team_2_home_or_away'
]

match_stats_selected = match_stats[selected_columns].copy()
features = match_stats.drop(columns=selected_columns).copy()

# %%
match_stats_selected
# Out:
#            date  match_id team_1_name  team_1_goalsScored  \
# 0    2000-08-21    213466     Arsenal                   2
# 1    2000-08-26    213475     Arsenal                   5
# 2    2000-09-16    213505     Arsenal                   2
# 3    2000-10-01    213532     Arsenal                   1
# 4    2000-10-14    213535     Arsenal                   1
# ...         ...       ...         ...                 ...
# 8810 2023-08-19    222209      Wolves                   1
# 8811 2023-09-16    222235      Wolves                   1
# 8812 2023-09-30    222261      Wolves                   2
# 8813 2023-10-08    222274      Wolves                   1
# 8814 2023-10-28    222290      Wolves                   2
#
#       team_1_halfTimeGoalsScored  team_1_cornerCount  team_1_shots  \
# 0                              1                  10            17
# 1                              1                   8            18
# 2                              1                   8            18
# 3                              1                   3             7
# 4                              0                   7            16
# ...                          ...                 ...           ...
# 8810                           0                   5            16
# 8811                           1                   4            11
# 8812                           1                   0             3
# 8813                           0                   2             8
# 8814                           1                   8            11
#
#       team_1_shotsOnTarget  team_1_foulsConceded  team_1_yellowConceded  ...  \
# 0                       12                    25                      2  ...
# 1                        9                    12                      0  ...
# 2                       13                     5                      1  ...
# 3                        5                    18                      2  ...
# 4                       10                    12                      1  ...
# ...                    ...                   ...                    ...  ...
# 8810                     5                    14                      3  ...
# 8811                     2                    10                      1  ...
# 8812                     1                    18                      5  ...
# 8813                     3                    19                      2  ...
# 8814                     6                    13                      1  ...
#
#       team_2_result  team_2_goalsConceded  team_2_halfTimeGoalsConceded  \
# 0               0.0                     2                             1
# 1               0.0                     5                             1
# 2               0.0                     2                             1
# 3               0.0                     1                             1
# 4               0.0                     1                             0
# ...             ...                   ...                           ...
# 8810            3.0                     1                             0
# 8811            3.0                     1                             1
# 8812            0.0                     2                             1
# 8813            1.0                     1                             0
# 8814            1.0                     2                             1
#
#       team_2_cornersConceded  team_2_shotsConceded  \
# 0                         10                    17
# 1                          8                    18
# 2                          8                    18
# 3                          3                     7
# 4                          7                    16
# ...                      ...                   ...
# 8810                       5                    16
# 8811                       4                    11
# 8812                       0                     3
# 8813                       2                     8
# 8814                       8                    11
#
#       team_2_shotsOnTargetConceded  team_2_foulsReceived  \
# 0                               12                    25
# 1                                9                    12
# 2                               13                     5
# 3                                5                    18
# 4                               10                    12
# ...                            ...                   ...
# 8810                             5                    14
# 8811                             2                    10
# 8812                             1                    18
# 8813                             3                    19
# 8814                             6                    13
#
#       team_2_yellowOpponent  team_2_redOpponent  team_2_home_or_away
# 0                         2                   1                 Away
# 1                         0                   0                 Away
# 2                         1                   0                 Away
# 3                         2                   0                 Away
# 4                         1                   0                 Away
# ...                     ...                 ...                  ...
# 8810                      3                   1                 Away
# 8811                      1                   0                 Away
# 8812                      5                   0                 Away
# 8813                      2                   1                 Away
# 8814                      1                   0                 Away
#
# [8815 rows x 40 columns]

# %%
features
# Out:
#       team_1_average_goalsScored_last_five  \
# 0                                      0.0
# 1                                      1.0
# 2                                      2.0
# 3                                      2.2
# 4                                      1.4
# ...                                    ...
# 8810                                   0.4
# 8811                                   0.8
# 8812                                   1.2
# 8813                                   1.4
# 8814                                   1.4
#
#       team_1_average_halfTimeGoalsScored_last_five  \
# 0                                              0.0
# 1                                              0.5
# 2                                              0.4
# 3                                              0.4
# 4                                              0.4
# ...                                            ...
# 8810                                           0.4
# 8811                                           0.0
# 8812                                           0.2
# 8813                                           0.4
# 8814                                           0.4
#
#       team_1_average_cornerCount_last_five  team_1_average_shots_last_five  \
# 0                                      9.0                            14.0
# 1                                      9.5                            15.5
# 2                                      8.6                            16.0
# 3                                      7.8                            15.4
# 4                                      6.8                            13.2
# ...                                    ...                             ...
# 8810                                   4.8                            10.6
# 8811                                   3.6                            13.6
# 8812                                   2.4                            10.6
# 8813                                   1.4                             8.0
# 8814                                   3.8                             9.0
#
#       team_1_average_shotsOnTarget_last_five  \
# 0                                        7.0
# 1                                        9.5
# 2                                        8.8
# 3                                        8.4
# 4                                        7.6
# ...                                      ...
# 8810                                     2.6
# 8811                                     3.4
# 8812                                     3.2
# 8813                                     2.4
# 8814                                     3.2
#
#       team_1_average_foulsConceded_last_five  \
# 0                                       21.0
# 1                                       23.0
# 2                                       18.6
# 3                                       13.0
# 4                                       14.2
# ...                                      ...
# 8810                                    13.6
# 8811                                    12.2
# 8812                                    13.4
# 8813                                    14.2
# 8814                                    14.8
#
#       team_1_average_yellowConceded_last_five  \
# 0                                         1.0
# 1                                         1.5
# 2                                         1.2
# 3                                         1.2
# 4                                         1.6
# ...                                       ...
# 8810                                      2.6
# 8811                                      2.6
# 8812                                      2.6
# 8813                                      3.0
# 8814                                      3.2
#
#       team_1_average_redConceded_last_five  team_1_average_result_last_five  \
# 0                                      1.0                              0.0
# 1                                      1.0                              1.5
# 2                                      0.4                              1.6
# 3                                      0.0                              1.8
# 4                                      0.0                              1.8
# ...                                    ...                              ...
# 8810                                   0.0                              0.8
# 8811                                   0.2                              0.6
# 8812                                   0.4                              0.8
# 8813                                   0.2                              1.4
# 8814                                   0.4                              1.6
#
#       team_1_average_goalsConceded_last_five  ...  \
# 0                                        1.0  ...
# 1                                        0.5  ...
# 2                                        1.4  ...
# 3                                        1.6  ...
# 4                                        1.0  ...
# ...                                      ...  ...
# 8810                                     1.8  ...
# 8811                                     2.6  ...
# 8812                                     2.2  ...
# 8813                                     1.6  ...
# 8814                                     1.4  ...
#
#       team_2_average_halfTimeGoalsConceded_last_five  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.4
# 3                                                0.4
# 4                                                0.6
# ...                                              ...
# 8810                                             1.0
# 8811                                             1.0
# 8812                                             0.4
# 8813                                             0.4
# 8814                                             0.2
#
#       team_2_average_cornersConceded_last_five  \
# 0                                          1.0
# 1                                          4.5
# 2                                          5.8
# 3                                          4.4
# 4                                          6.0
# ...                                        ...
# 8810                                       4.2
# 8811                                       3.2
# 8812                                       3.2
# 8813                                       4.2
# 8814                                       4.0
#
#       team_2_average_shotsConceded_last_five  \
# 0                                        3.0
# 1                                       10.5
# 2                                       13.2
# 3                                        9.4
# 4                                       11.4
# ...                                      ...
# 8810                                    12.2
# 8811                                    14.0
# 8812                                     7.0
# 8813                                    10.6
# 8814                                    10.0
#
#       team_2_average_shotsOnTargetConceded_last_five  \
# 0                                                2.0
# 1                                                6.0
# 2                                                5.8
# 3                                                4.4
# 4                                                5.4
# ...                                              ...
# 8810                                             4.4
# 8811                                             6.0
# 8812                                             2.6
# 8813                                             3.2
# 8814                                             2.2
#
#       team_2_average_foulsReceived_last_five  \
# 0                                        8.0
# 1                                       14.5
# 2                                       15.6
# 3                                       13.0
# 4                                        8.4
# ...                                      ...
# 8810                                    12.8
# 8811                                     9.0
# 8812                                    11.6
# 8813                                    12.6
# 8814                                    12.4
#
#       team_2_average_yellowOpponent_last_five  \
# 0                                         1.0
# 1                                         2.0
# 2                                         2.6
# 3                                         2.2
# 4                                         1.4
# ...                                       ...
# 8810                                      2.8
# 8811                                      1.6
# 8812                                      4.4
# 8813                                      2.2
# 8814                                      3.4
#
#       team_2_average_redOpponent_last_five  team_2_promoted  \
# 0                                      0.0                0
# 1                                      0.0                0
# 2                                      0.0                0
# 3                                      0.0                0
# 4                                      0.0                0
# ...                                    ...              ...
# 8810                                   0.0                0
# 8811                                   0.0                0
# 8812                                   0.0                0
# 8813                                   0.0                0
# 8814                                   0.0                0
#
#       team_2_win_streak_before_match  team_2_unbeaten_streak_before_match
# 0                                  1                                    1
# 1                                  0                                    0
# 2                                  0                                    1
# 3                                  0                                    7
# 4                                  1                                    4
# ...                              ...                                  ...
# 8810                               1                                    1
# 8811                               3                                   15
# 8812                               6                                    6
# 8813                               3                                    3
# 8814                               1                                    5
#
# [8815 rows x 40 columns]

# %% [markdown]
# Trenowanie modeli

# %%
train_data = match_stats[match_stats['date'] < '2018-07-01']
test_data = match_stats[match_stats['date'] >= '2018-07-01']
test_data = test_data[test_data['date'] < '2023-10-01']
upcoming_matches = match_stats[match_stats['date'] >= '2023-10-01']

X_train = train_data[features.columns]
X_test = test_data[features.columns]
Y_train_team1 = train_data['team_1_goalsScored']
Y_test_team1 = test_data['team_1_goalsScored']
Y_train_team2 = train_data['team_2_goalsScored']
Y_test_team2 = test_data['team_2_goalsScored']

# %%
def get_match_result(row):
    if row['team_1_goalsScored'] > row['team_2_goalsScored']:
        return 1   # wygrana team_1
    elif row['team_1_goalsScored'] < row['team_2_goalsScored']:
        return -1  # wygrana team_2
    else:
        return 0   # remis

# %%
train_data["result"] = train_data.apply(get_match_result, axis=1)
test_data["result"] = test_data.apply(get_match_result, axis=1)

# %%
from xgboost import XGBClassifier

# %%
X_train = train_data[features.columns]
X_test = test_data[features.columns]

y_train = train_data["result"]
y_test = test_data["result"]

# %%
mapping = {-1: 0, 0: 1, 1: 2}

y_train = train_data["result"].map(mapping)
y_test = test_data["result"].map(mapping)

# %%
from xgboost import XGBClassifier

model = XGBClassifier(
    objective="multi:softprob",
    num_class=3,
    eval_metric="mlogloss",
    learning_rate=0.05,
    max_depth=6,
    n_estimators=400,
    subsample=0.9,
    colsample_bytree=0.9
)

model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.9, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=400, n_jobs=None, num_class=3, ...)

# %%
probs = model.predict_proba(X_test)

# %%
predicted = pd.DataFrame({
    "team_2_win_prob": probs[:, 0],
    "draw_prob": probs[:, 1],
    "team_1_win_prob": probs[:, 2]
})

# %%
X_upcoming = upcoming_matches[features.columns]
upcoming_probs = model.predict_proba(X_upcoming)

upcoming_predictions = pd.DataFrame({
    "team_1_name": upcoming_matches["team_1_name"].values,
    "team_2_name": upcoming_matches["team_2_name"].values,
    "team_1_win_prob": upcoming_probs[:, 2],
    "draw_prob": upcoming_probs[:, 1],
    "team_2_win_prob": upcoming_probs[:, 0],
})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 X_upcoming = upcoming_matches[features.columns]
#       2 upcoming_probs = model.predict_proba(X_upcoming)
#       4 upcoming_predictions = pd.DataFrame({
#       5     "team_1_name": upcoming_matches["team_1_name"].values,
#       6     "team_2_name": upcoming_matches["team_2_name"].values,
#    (...)
#       9     "team_2_win_prob": upcoming_probs[:, 0],
#      10 })
#
# File c:\Users\mateu\anaconda3\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\mateu\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File c:\Users\mateu\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['team_1_average_goalsScored_last_five',\n       'team_1_average_halfTimeGoalsScored_last_five',\n       'team_1_average_cornerCount_last_five',\n       'team_1_average_shots_last_five',\n       'team_1_average_shotsOnTarget_last_five',\n       'team_1_average_foulsConceded_last_five',\n       'team_1_average_yellowConceded_last_five',\n       'team_1_average_redConceded_last_five',\n       'team_1_average_result_last_five',\n       'team_1_average_goalsConceded_last_five',\n       'team_1_average_halfTimeGoalsConceded_last_five',\n       'team_1_average_cornersConceded_last_five',\n       'team_1_average_shotsConceded_last_five',\n       'team_1_average_shotsOnTargetConceded_last_five',\n       'team_1_average_foulsReceived_last_five',\n       'team_1_average_yellowOpponent_last_five',\n       'team_1_average_redOpponent_last_five', 'team_1_promoted',\n       'team_1_win_streak_before_match', 'team_1_unbeaten_streak_before_match',\n       'team_2_average_goalsScored_last_five',\n       'team_2_average_halfTimeGoalsScored_last_five',\n       'team_2_average_cornerCount_last_five',\n       'team_2_average_shots_last_five',\n       'team_2_average_shotsOnTarget_last_five',\n       'team_2_average_foulsConceded_last_five',\n       'team_2_average_yellowConceded_last_five',\n       'team_2_average_redConceded_last_five',\n       'team_2_average_result_last_five',\n       'team_2_average_goalsConceded_last_five',\n       'team_2_average_halfTimeGoalsConceded_last_five',\n       'team_2_average_cornersConceded_last_five',\n       'team_2_average_shotsConceded_last_five',\n       'team_2_average_shotsOnTargetConceded_last_five',\n       'team_2_average_foulsReceived_last_five',\n       'team_2_average_yellowOpponent_last_five',\n       'team_2_average_redOpponent_last_five', 'team_2_promoted',\n       'team_2_win_streak_before_match',\n       'team_2_unbeaten_streak_before_match'],\n      dtype='object')] are in the [columns]"

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, r2_score
import joblib

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\mateu\anaconda3\lib\site-packages (3.1.2)
# Requirement already satisfied: numpy in c:\users\mateu\anaconda3\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\mateu\anaconda3\lib\site-packages (from xgboost) (1.13.1)

# %%
import pickle
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression

from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# Nazwy i modele regresyjne
names = [
    "Linear Regression",
    "Random Forest",
    "Decision Tree",
    "Support Vector Regressor",
    "XGBoost"
]

regressors = [
    LinearRegression(),
    RandomForestRegressor(max_depth=5, n_estimators=100, max_features='sqrt', random_state=42),
    DecisionTreeRegressor(max_depth=6, random_state=42),
    make_pipeline(StandardScaler(), SVR(kernel='rbf', C=1.0, epsilon=0.1)),
    XGBRegressor(n_estimators=200, max_depth=5, learning_rate=0.05, subsample=0.8, colsample_bytree=0.8, random_state=42),
]


# Define file paths for saving the models
model_save_paths = {name: f'{name}_model.pkl' for name in names}

# Train models and save them as pickle files for team_1_goalsScored
for name, reg in zip(names, regressors):
    # Fit the regressor on the training data for team_1_goalsScored
    reg.fit(X_train, Y_train_team1)

    # Save the model to a pickle file
    with open(model_save_paths[name] + '_team1', 'wb') as f:
        pickle.dump(reg, f)

    # Make predictions on the test data
    test_data[name + '_team_1_goalsScored'] = reg.predict(X_test)
    mse_team1 = mean_squared_error(Y_test_team1, test_data[name + '_team_1_goalsScored'])
    r2_team1 = r2_score(Y_test_team1, test_data[name + '_team_1_goalsScored'])

    # Print evaluation metrics for each regressor
    print(f'{name} Team 1 GoalsScored MSE: {mse_team1}')
    print(f'{name} Team 1 GoalsScored R^2: {r2_team1}')

# Train models and save them as pickle files for team_2_goalsScored
for name, reg in zip(names, regressors):
    # Fit the regressor on the training data for team_2_goalsScored
    reg.fit(X_train, Y_train_team2)

    # Save the model to a pickle file
    with open(model_save_paths[name] + '_team2', 'wb') as f:
        pickle.dump(reg, f)

    # Make predictions on the test data
    test_data[name + '_team_2_goalsScored'] = reg.predict(X_test)
    mse_team2 = mean_squared_error(Y_test_team2, test_data[name + '_team_2_goalsScored'])
    r2_team2 = r2_score(Y_test_team2, test_data[name + '_team_2_goalsScored'])

    # Print evaluation metrics for each regressor
    print(f'{name} Team 2 GoalsScored MSE: {mse_team2}')
    print(f'{name} Team 2 GoalsScored R^2: {r2_team2}')

for name in names:
    # wczytaj zapisane modele
    with open(model_save_paths[name] + '_team1', 'rb') as f:
        mdl1 = pickle.load(f)
    with open(model_save_paths[name] + '_team2', 'rb') as f:
        mdl2 = pickle.load(f)

    # predykcje na train
    p1_train = mdl1.predict(X_train)
    p2_train = mdl2.predict(X_train)
    pred_outcome_train = np.where(np.isclose(p1_train, p2_train, atol=0.2), 1, np.where(p1_train > p2_train, 3, 0))
    true_outcome_train = train_data['team_1_result'].values
    try:
        train_acc = np.mean(pred_outcome_train == true_outcome_train)
    except Exception:
        train_acc = np.nan

    # predykcje na test
    p1_test = mdl1.predict(X_test)
    p2_test = mdl2.predict(X_test)
    pred_outcome_test = np.where(np.isclose(p1_test, p2_test, atol=0.2), 1, np.where(p1_test > p2_test, 3, 0))
    true_outcome_test = test_data['team_1_result'].values
    mask = ~np.isnan(true_outcome_test)
    if mask.sum() == 0:
        test_acc = np.nan
    else:
        test_acc = np.mean(pred_outcome_test[mask] == true_outcome_test[mask])

    print(f'{name} train_outcome_acc: {train_acc:.4f} | test_outcome_acc: {test_acc:.4f}')

# Apply the saved models to the 'upcoming_matches' dataframe for team_1_goalsScored and team_2_goalsScored
for name, reg in zip(names, regressors):
    # Load the models from the pickle files
    with open(model_save_paths[name] + '_team1', 'rb') as f:
        loaded_model_team1 = pickle.load(f)
    with open(model_save_paths[name] + '_team2', 'rb') as f:
        loaded_model_team2 = pickle.load(f)

    # Predict team_1_goalsScored and team_2_goalsScored for upcoming matches
    upcoming_matches[name + '_team_1_goalsScored'] = loaded_model_team1.predict(upcoming_matches[features.columns])
    upcoming_matches[name + '_team_2_goalsScored'] = loaded_model_team2.predict(upcoming_matches[features.columns])
# Out:
# Linear Regression Team 1 GoalsScored MSE: 1.552327069060905
# Linear Regression Team 1 GoalsScored R^2: 0.12199308945326681
# Random Forest Team 1 GoalsScored MSE: 1.5788875695597993
# Random Forest Team 1 GoalsScored R^2: 0.10697028694572763
# Decision Tree Team 1 GoalsScored MSE: 1.7871668570476862
# Decision Tree Team 1 GoalsScored R^2: -0.010833916422795742
# Support Vector Regressor Team 1 GoalsScored MSE: 1.674750752996253
# Support Vector Regressor Team 1 GoalsScored R^2: 0.05274940836816455
# XGBoost Team 1 GoalsScored MSE: 1.5973916137582196
# XGBoost Team 1 GoalsScored R^2: 0.09650421142578125
# Linear Regression Team 2 GoalsScored MSE: 1.3661576604594212
# Linear Regression Team 2 GoalsScored R^2: 0.08555698502190667
# Random Forest Team 2 GoalsScored MSE: 1.3911770138181065
# Random Forest Team 2 GoalsScored R^2: 0.06881018223310942
# Decision Tree Team 2 GoalsScored MSE: 1.4933085699857802
# Decision Tree Team 2 GoalsScored R^2: 0.0004480225428692419
# Support Vector Regressor Team 2 GoalsScored MSE: 1.511119678887762
# Support Vector Regressor Team 2 GoalsScored R^2: -0.011473913406276015
# XGBoost Team 2 GoalsScored MSE: 1.4107937252230012
# XGBoost Team 2 GoalsScored R^2: 0.05567961931228638
# Linear Regression train_outcome_acc: 0.5006 | test_outcome_acc: 0.4969
# Random Forest train_outcome_acc: 0.5034 | test_outcome_acc: 0.4852
# Decision Tree train_outcome_acc: 0.5031 | test_outcome_acc: 0.4822
# Support Vector Regressor train_outcome_acc: 0.6206 | test_outcome_acc: 0.4852
# XGBoost train_outcome_acc: 0.5994 | test_outcome_acc: 0.4995
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[83], line 109
#     106     loaded_model_team2 = pickle.load(f)
#     108 # Predict team_1_goalsScored and team_2_goalsScored for upcoming matches
# --> 109 upcoming_matches[name + '_team_1_goalsScored'] = loaded_model_team1.predict(upcoming_matches[features.columns])
#     110 upcoming_matches[name + '_team_2_goalsScored'] = loaded_model_team2.predict(upcoming_matches[features.columns])
#
# File c:\Users\mateu\anaconda3\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\mateu\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File c:\Users\mateu\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['team_1_average_goalsScored_last_five',\n       'team_1_average_halfTimeGoalsScored_last_five',\n       'team_1_average_cornerCount_last_five',\n       'team_1_average_shots_last_five',\n       'team_1_average_shotsOnTarget_last_five',\n       'team_1_average_foulsConceded_last_five',\n       'team_1_average_yellowConceded_last_five',\n       'team_1_average_redConceded_last_five',\n       'team_1_average_result_last_five',\n       'team_1_average_goalsConceded_last_five',\n       'team_1_average_halfTimeGoalsConceded_last_five',\n       'team_1_average_cornersConceded_last_five',\n       'team_1_average_shotsConceded_last_five',\n       'team_1_average_shotsOnTargetConceded_last_five',\n       'team_1_average_foulsReceived_last_five',\n       'team_1_average_yellowOpponent_last_five',\n       'team_1_average_redOpponent_last_five', 'team_1_promoted',\n       'team_1_win_streak_before_match', 'team_1_unbeaten_streak_before_match',\n       'team_2_average_goalsScored_last_five',\n       'team_2_average_halfTimeGoalsScored_last_five',\n       'team_2_average_cornerCount_last_five',\n       'team_2_average_shots_last_five',\n       'team_2_average_shotsOnTarget_last_five',\n       'team_2_average_foulsConceded_last_five',\n       'team_2_average_yellowConceded_last_five',\n       'team_2_average_redConceded_last_five',\n       'team_2_average_result_last_five',\n       'team_2_average_goalsConceded_last_five',\n       'team_2_average_halfTimeGoalsConceded_last_five',\n       'team_2_average_cornersConceded_last_five',\n       'team_2_average_shotsConceded_last_five',\n       'team_2_average_shotsOnTargetConceded_last_five',\n       'team_2_average_foulsReceived_last_five',\n       'team_2_average_yellowOpponent_last_five',\n       'team_2_average_redOpponent_last_five', 'team_2_promoted',\n       'team_2_win_streak_before_match',\n       'team_2_unbeaten_streak_before_match'],\n      dtype='object')] are in the [columns]"

# %%
# Export the predictions for upcoming matches to a CSV file
upcoming_matches=upcoming_matches[['date',
                                    'match_id',
                                    'team_1_name',
                                    'team_2_name',
                                    'Linear Regression_team_1_goalsScored',
                                    'Linear Regression_team_2_goalsScored',
                                    'Random Forest_team_1_goalsScored',
                                    'Random Forest_team_2_goalsScored',
                                    'Decision Tree_team_1_goalsScored',
                                    'Decision Tree_team_2_goalsScored',
                                    'Support Vector Regressor_team_1_goalsScored',
                                    'Support Vector Regressor_team_2_goalsScored',
                                    'XGBoost_team_1_goalsScored',
                                    'XGBoost_team_2_goalsScored'
                                    ]]
upcoming_matches.to_csv('upcoming_matches_goals_predictions.csv', index=False)


# Evaluate upcoming_matches predictions by joining true results from match_stats (match_id must match)
preds = upcoming_matches.copy()

# bring true results from match_stats
truth_cols = ['match_id','team_1_goalsScored','team_2_goalsScored','team_1_result']
truth = match_stats[truth_cols].drop_duplicates(subset='match_id')
preds = preds.merge(truth, on='match_id', how='left', suffixes=('','_true'))

import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

eval_rows = []
for name in names:
    p1 = preds[f'{name}_team_1_goalsScored'].values
    p2 = preds[f'{name}_team_2_goalsScored'].values
    t1 = preds['team_1_goalsScored'].values
    t2 = preds['team_2_goalsScored'].values

    mask = ~np.isnan(t1) 
    if mask.sum() == 0:
        print(f'Brak prawdziwych wyników dla modelu {name}')
        continue

    p1m, p2m, t1m, t2m = p1[mask], p2[mask], t1[mask], t2[mask]

    mse1 = mean_squared_error(t1m, p1m)
    #mae1 = mean_absolute_error(t1m, p1m)
    r21 = r2_score(t1m, p1m)
    mse2 = mean_squared_error(t2m, p2m)
    #mae2 = mean_absolute_error(t2m, p2m)
    r22 = r2_score(t2m, p2m)

    exact_score_acc = np.mean((np.rint(p1m) == t1m) & (np.rint(p2m) == t2m))

    pred_outcome = np.where(np.isclose(p1m, p2m, atol=0.2), 1, np.where(p1m > p2m, 3, 0))
    true_outcome = preds.loc[mask, 'team_1_result'].values
    outcome_acc = np.mean(pred_outcome == true_outcome)
    

    eval_rows.append({
        'model': name,
        'team1_mse': mse1, 'team1_r2': r21,
        'team2_mse': mse2, 'team2_r2': r22,
        'exact_score_acc': exact_score_acc,
        'outcome_acc': outcome_acc,
        'n_matches': int(mask.sum())
    })

eval_df = pd.DataFrame(eval_rows)
print('\nUpcoming matches evaluation:')
print(eval_df)
# Out:
# Upcoming matches evaluation:
#                       model  team1_mse  team1_r2  team2_mse  team2_r2  \
# 0         Linear Regression   1.384101  0.262052   0.935550  0.078896
# 1             Random Forest   1.510048  0.194902   0.980501  0.034639
# 2             Decision Tree   1.768953  0.056865   1.138373 -0.120795
# 3  Support Vector Regressor   1.649913  0.120332   1.015753 -0.000067
# 4                   XGBoost   1.408884  0.248839   1.039292 -0.023244
#
#    exact_score_acc  outcome_acc  n_matches
# 0         0.186047     0.488372         43
# 1         0.139535     0.465116         43
# 2         0.139535     0.465116         43
# 3         0.162791     0.511628         43
# 4         0.139535     0.534884         43
